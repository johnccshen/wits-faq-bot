# %%
import pandas as pd

# %%
faq_file_path = '../data/FAQ_JOHN_REVIEW.xlsx'

# %%
df = pd.read_excel(faq_file_path, sheet_name=None)

# %%
df.keys()
# Out:
# dict_keys(['230323'])

# %%
df_curr = df['230323']

# %%
df_curr.to_csv('../data/faq-train.csv', index=False)

# %%
df_curr
# Out:
#     Department  Category                            Question  \
# 0      Finance  BPM-費用報銷                   申請【交通費】報銷方式及檢附單據？
# 1      Finance  BPM-費用報銷  一趟公務交通費就需要提交一張表單嗎？還是同性質的可以填在同一張即可？
# 2      Finance  BPM-費用報銷            計程車或是高鐵費用的未稅金額及營業稅該如何填寫？
# 3      Finance  BPM-費用報銷                   申請【交際費】報銷方式及檢附單據？
# 4      Finance  BPM-費用報銷                     送禮給客戶，費用有沒有上限呢？
# ..         ...       ...                                 ...
# 208         HR      行政總務                     識別證掛繩若損壞破舊可以換嗎？
# 209         HR      疫情相關              我要到哪裡填寫醫療關懷系統，登錄每天的體溫？
# 210         HR      疫情相關                  我想知道疫情期間有什麼假別可以使用？
# 211         HR      疫情相關                         公司有提供快篩試劑嗎？
# 212         HR        其他         發現公司人員涉有違法、不當、不道德之情事，該如何舉報？
#
#                                                 Answer  \
# 0    1.BPM申請類別【一般支出】及檢附【TA605-02交通費用申請單(如下方附件檔案)】，並...
# 1               可以。可多筆交通費一起報銷，請參閱問題【申請【交通費】報銷方式及檢附單據？】
# 2    1.計程車無營業稅。\n2.高鐵車票：\n未稅金額=>車票總金額/1.05\n營業稅稅金=>...
# ...

# %%
import os
import openai

openai.api_key = "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"

response = openai.Completion.create(
    model="text-davinci-003",
    prompt="講個笑話來聽聽",
    max_tokens=128,
    temperature=0.5,
)

completed_text = response["choices"][0]["text"]
print(completed_text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 6
#       2 import openai
#       4 openai.api_key = "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"
# ----> 6 response = openai.Completion.create(
#       7     model="text-davinci-003",
#       8     prompt="講個笑話來聽聽",
#       9     max_tokens=128,
#      10     temperature=0.5,
#      11 )
#      13 completed_text = response["choices"][0]["text"]
#      14 print(completed_text)
#
# File /opt/anaconda3/envs/faq-bot/lib/python3.11/site-packages/openai/api_resources/completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# ...
